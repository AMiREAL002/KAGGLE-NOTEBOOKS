# %% [markdown]
# <a href="https://www.kaggle.com/code/subhammudi/02-03-2022-ml-lab-1?scriptVersionId=93356382" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
#now getting started with dataset
df=pd.read_csv('../input/iris/Iris.csv')
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(df.head(4))
print(df.tail(6))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# ...

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
print(df.shape)
print(df.size)
# Out:
# (150, 6)
# 900

# %%
print(df.count())
print(df.mean())
print(df.std())
print(df.min())
print(df.max())
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object
# ...

# %%
#I want to drop all records having missing value or NaN value
df.dropna()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df_SepalWidthCm=df.groupby(['SepalWidthCm'])
df_SepalWidthCm.mean()
# Out:
#                       Id  SepalLengthCm  PetalLengthCm  PetalWidthCm
# SepalWidthCm
# 2.0            61.000000       5.000000       3.500000      1.000000
# 2.2            84.000000       6.066667       4.500000      1.333333
# 2.3            69.500000       5.325000       3.250000      0.975000
# 2.4            73.666667       5.300000       3.600000      1.033333
# 2.5           101.125000       5.762500       4.512500      1.550000
# 2.6           103.600000       6.160000       4.880000      1.420000
# 2.7            96.777778       5.855556       4.622222      1.555556
# 2.8           103.428571       6.335714       5.042857      1.707143
# 2.9            75.800000       6.060000       4.350000      1.320000
# 3.0            88.692308       6.015385       4.234615      1.403846
# 3.1            73.750000       5.941667       3.600000      1.141667
# 3.2            73.230769       5.884615       3.753846      1.261538
# ...

# %%
#Dataframe filtering can also be done
df_s = df[ df['Species'] == 'Iris-virginica' ]
print(df_s)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
df.iloc[50:60]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
# 55  56            5.7           2.8            4.5           1.3
# 56  57            6.3           3.3            4.7           1.6
# 57  58            4.9           2.4            3.3           1.0
# 58  59            6.6           2.9            4.6           1.3
# 59  60            5.2           2.7            3.9           1.4
#
#             Species
# 50  Iris-versicolor
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor
# 56  Iris-versicolor
# 57  Iris-versicolor
# 58  Iris-versicolor
# 59  Iris-versicolor

# %%
df.loc[50:60,['SepalWidthCm']]
# Out:
#     SepalWidthCm
# 50           3.2
# 51           3.2
# 52           3.1
# 53           2.3
# 54           2.8
# 55           2.8
# 56           3.3
# 57           2.4
# 58           2.9
# 59           2.7
# 60           2.0
